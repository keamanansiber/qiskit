# %%
from qiskit.circuit.library import QFT
from qiskit.quantum_info import Statevector
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector, plot_bloch_vector
#import warnings
#warnings.filterwarnings('ignore')

# %%
def Demo(state):

    mycircuit = QuantumCircuit(len(state))
    mycircuit.initialize(Statevector.from_label(state).data, mycircuit.qubits[::-1])

    print(f'Computational Basis |{state}> ')
    display(plot_bloch_multivector(Statevector.from_instruction(mycircuit).data))

    print(f'FOURIER Basis |{state}> ')
    mycircuit.append(QFT(len(state), do_swaps=True), mycircuit.qubits)
    display(plot_bloch_multivector(Statevector.from_instruction(mycircuit).data))

# %%
state = '001'
Demo(state)
# Out:
# Computational Basis |001>
# FOURIER Basis |001>

# %%
Demo('000')
Demo('001')
Demo('010')
Demo('011')
Demo('100')
Demo('101')
Demo('110')
Demo('111')
# Out:
# Computational Basis |000>
# FOURIER Basis |000>
# Computational Basis |001>
# FOURIER Basis |001>
# Computational Basis |010>
# FOURIER Basis |010>
# Computational Basis |011>
# FOURIER Basis |011>
# Computational Basis |100>
# FOURIER Basis |100>
# Computational Basis |101>
# FOURIER Basis |101>
# Computational Basis |110>
# FOURIER Basis |110>
# Computational Basis |111>
# FOURIER Basis |111>
